# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/last.pt")
# Out:
# WARNING  Python>=3.10 is required, but Python==3.9.20 is currently installed
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Admin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import matplotlib.pyplot as plt
image_path = r"C:\Users\Admin\Downloads\images.png"

results = model(image_path)

predicted_image = results[0].plot()
plt.imshow(predicted_image)
plt.show()
# Out:
# image 1/1 C:\Users\Admin\Downloads\images.png: 384x640 1 2-2 Nonflammable gases, 1 2-3 Toxic gases, 1 3 Flammable, 107.9ms
# Speed: 1.9ms preprocess, 107.9ms inference, 15.4ms postprocess per image at shape (1, 3, 384, 640)
